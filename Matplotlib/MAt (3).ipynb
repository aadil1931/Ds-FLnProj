# %%
import pandas as pd

# %%
n1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
                  'B': ['B0','B1','B2','B3'],
                  'C': ['C0','C1','C2','C3'],
                  'D': ['D0','D1','D2','D3']},
                 index=[0,1,2,3])

# %%
nw = pd.DataFrame({'A':['A4','A5','A6','A7'],
                  'B': ['B4','B5','B6','B7'], 
                  'C': ['C4','C5','C6','C7'],
                  'D': ['D4','D5','D6','D7']},
                 index=[4,5,6,7])

# %%
n3 = pd.DataFrame({'A':['A8','A9','A10','A11'],
                  'B': ['B8','B9','B10','B11'],
                  'C': ['C8','C9','C10','C11'],
                  'D': ['D8','D9','D10','D11']},
                 index=[8,9,10,11])

# %%
display(df1,df2,df3,pd.concat([df1,df2,df3]))
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['k0','k2','k2','k3'],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']})

right = pd.DataFrame({'key': ['k0','k1','k2','k0'],
                    'C':['C0','C1','C2','C3'],
                    'D':['D0','D1','D2','D3']})

# %%
display(left,right,pd.merge(left,right,how='outer',on=['key']))
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k2  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3
#   key   C   D
# 0  k0  C0  D0
# 1  k1  C1  D1
# 2  k2  C2  D2
# 3  k0  C3  D3
#   key    A    B    C    D
# 0  k0   A0   B0   C0   D0
# 1  k0   A0   B0   C3   D3
# 2  k2   A1   B1   C2   D2
# 3  k2   A2   B2   C2   D2
# 4  k3   A3   B3  NaN  NaN
# 5  k1  NaN  NaN   C1   D1

# %%
pd.merge(left,right,how='inner',on=['key'])
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k0  A0  B0  C3  D3
# 2  k2  A1  B1  C2  D2
# 3  k2  A2  B2  C2  D2

# %%
pd.merge(left,right,how='left',on=['key'])
# Out:
#   key   A   B    C    D
# 0  k0  A0  B0   C0   D0
# 1  k0  A0  B0   C3   D3
# 2  k2  A1  B1   C2   D2
# 3  k2  A2  B2   C2   D2
# 4  k3  A3  B3  NaN  NaN

# %%
pd.merge(left,right,how='right',on=['key'])
# Out:
#   key    A    B   C   D
# 0  k0   A0   B0  C0  D0
# 1  k1  NaN  NaN  C1  D1
# 2  k2   A1   B1  C2  D2
# 3  k2   A2   B2  C2  D2
# 4  k0   A0   B0  C3  D3

# %%
left.set_index('key',inplace=True)

# %%
##Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y, + 0,linestyle='dotted')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'v')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'s')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'d')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'<')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'>')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'-ok')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'+')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.xlim(-10,100)
plt.ylim(-10,50)
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.xlim(10,-10)
plt.ylim(50,-5)
plt.title('chart')
plt.show()

# %%
plt.plot(x,y,'g^-')
plt.xlabel('x axis title here')
plt.ylabel('y axis title here')
plt.xlim(10,-10)
plt.ylim(50,-5)
plt.title('chart')
plt.show()

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'mv-')
plt.xlabel('x axis ')
plt.ylabel('y axis ')
plt.subplot(1,3,2)
plt.plot(x,y,'b*-')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(-10,20)
plt.ylim(-5,30)
plt.title('chart')
plt.show()

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'mv-')
plt.xlabel('x axis ')
plt.ylabel('y axis ')
plt.subplot(1,3,2)
plt.plot(y,x,'b*-')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('chart')
plt.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.3,0.3])
axes.plot(x,y,'black')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('set titile')
# Out:
# Text(0.5, 1.0, 'set titile')

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randint(1,100,(4,3)),
index=['riya','siya','kiya','jiya'], 
columns=['python','datascience','dbms'])
df
# Out:
#       python  datascience  dbms
# riya      40           79    66
# siya      31            1    73
# kiya      15           35    48
# jiya       4           47    47

# %%
plt.plot(df.index,df.python,'rs:')
plt.plot(df.index,df.datascience,'bv-')

# %%
fig=plt.figure()
ax=fig.add_axes([.1,.1,.5,.5])
ax.plot(df.index,df.python)

# %%
f,ax=plt.subplots(1,3)

# %%
fig,ax = plt.subplots(2,2,layout='constrained',sharex=True,sharey=True)

# %%
ax[0,0].plot(df.index,df.python,'rs:')
ax[0,0].set_title('python')

ax[0,1].plot(df.index,df.datascience,'bv-')
ax[0,1].set_title('datasciene')

ax[1,0].plot(df.index,df.dbms,'rs:')
ax[1,0].set_title('dbms')

ax[1,1].plot(df.index,df.python,df.datascience,df.dbms,'bv-')
ax[1,1].set_title
# Out:
# <bound method Axes.set_title of <Axes: >>

# %%
f

# %%
ax[1,1].plot(df.index,df.dbms,'gs:')
ax[0,0].plot(df.index,df.python,'r',label='py')
ax[0,0].set_xlabel('name')
ax[0,0].set_ylabel('python marks')
ax[0,0].set_title('python');
ax[0,0].legend()

ax[1,1].plot(df.index,df.datascience,'gv-',linewidth=0.25)
ax[0,0].set_xlabel('name')
ax[0,0].set_ylabel('datascience marks')
ax[0,0].set_title('data science');
fig

# %%
ax[1,1].plot(df.index,df.datascience)
ax[1,1].plot(df.index,df.dbms)
fig

# %%
a=np.arange(10)
b=a**2
plt.scatter(a,b,s=100)

# %%
fig,ax = plt.subplots(1,4,sharex=True,sharey=True)

# %%
a=np.arange(10)
b=a**2
c1=np.random.randint(0,100,10)
plt.scatter(a,b,c= c1,s=100,edgecolors="blue",marker="p",linewidth=1.75)

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 100 * np.random.rand(50)
plt.scatter(x,y, c=colors,s=sizes,alpha=0.7,cmap='brg')
plt.colorbar()

# %%
from random import sample 
data = sample(range(1,1000),100)
plt.hist(data,linewidth=0.9,edgecolor="red")
# Out:
# (array([11., 10.,  6., 12., 12.,  9., 13.,  8., 12.,  7.]),
#  array([ 15. , 112.2, 209.4, 306.6, 403.8, 501. , 598.2, 695.4, 792.6,
#         889.8, 987. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stairs(data)

# %%
x = np.arange(0,10,2)
ay = [1,1.25,2,2.75,3]
by = [1,1,1,1,1]
cy = [2,1,2,1,2]
y = np.vstack([ay,by,cy])
fig,ax=plt.subplots()
ax.stackplot(x,y)
ax.set(xlim=(0,8), xticks=np.arange(1,8),
      ylim=(0,8),yticks=np.arange(1,8))
plt.show()

# %%
x = [1,2,3,4]
plt.pie(x, radius=3,center=(4,4),frame=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x14c5198f990>,
# ...
#  [Text(7.138486499000184, 5.019756096129642, ''),
#   Text(5.019756022668064, 7.1384865228692975, ''),
#   Text(0.8615134293924815, 5.019755875744905, ''),
#   Text(5.019756463437526, 0.861513620345407, '')])

# %%
f=np.random.normal(0,100,50)
plt.boxplot(f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c51a18b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c51a19e90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c519db950>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c51a1b290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c51a1bd50>],
#  'means': []}

# %%
data=[np.random.normal(0,std,100)for std in range (1,4)]

plt.boxplot(data,vert=False,patch_artist=True);

# %%
plt.hexbin(a,b,gridsize=30)

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(tips['total_bill'])
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
## pairplot

# %%
sns.pairplot(tips,hue='sex',palette='brg')
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
tit=sns.load_dataset('titanic')
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
##clustermap
clustermap uses hierarchal clustering

# %%
sns.barplot(x='tip',y='total_bill',data= tips)

# %%
sns.countplot(x='tip',data=tips,ax=None)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
tit=sns.load_dataset('titanic')
tit.head()

# %%
sns.jointplot(tit,x='age',y='fare')

# %%
sns.displot(tit,x='age',y='fare')

# %%
sns.swarmplot(tit,x='class',y='age')

# %%
sns.countplot(tit,x='class')

# %%
sns.heatmap(tit.corr(numeric_only=True))

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 

from skllearn.datasets import load_iris
from sklearn..cluster import KMeans

# %%
x, y = load_iris(return_x_y= True)

# %%
y

# %%
print('hello')
